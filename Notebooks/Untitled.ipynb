# %% [markdown]
# # Tabela de Numero de viagens feitas por turistas

# %%
import matplotlib.pyplot as plt
import pandas as pd

#Associação do data frame ao csv em análise
dataframe_tur = pd.read_csv('N_viagens_de_ turistas_por_sexo_e_meio_de_transporte.csv')

dataframe_tur
# Out:
#       Id       Meses  Local_de_residencia  Sexo  Meio_de_transporte  \
# 0      1    Dezembro             Portugal    HM           Terrestre
# 1      2    Novembro             Portugal    HM           Terrestre
# 2      3     Outubro             Portugal    HM           Terrestre
# 3      4    Setembro             Portugal    HM           Terrestre
# 4      5      Agosto             Portugal    HM           Terrestre
# ..   ...         ...                  ...   ...                 ...
# 127  128        Maio             Portugal    HM           Terrestre
# 128  129       Abril             Portugal    HM           Terrestre
# 129  130       Marco             Portugal    HM           Terrestre
# 130  131   Fevereiro             Portugal    HM           Terrestre
# 131  132     Janeiro             Portugal    HM           Terrestre
#
#       N_de_viagens   Ano
# 0           979908  2020
# 1           541469  2020
# 2           828561  2020
# 3          1398486  2020
# 4          3154781  2020
# ..             ...   ...
# 127         868843  2010
# 128        1130322  2010
# 129         877641  2010
# 130        1036056  2010
# 131         908819  2010
#
# [132 rows x 7 columns]

# %% [markdown]
# ## Ano mais recente em análise

# %%
#função head lê os primeiros dados da tabela, neste caso, definimos que lia os primeiros 12
dataframe_tur.head(12)
# Out:
#     Id       Meses  Local_de_residencia  Sexo  Meio_de_transporte  \
# 0    1    Dezembro             Portugal    HM           Terrestre
# 1    2    Novembro             Portugal    HM           Terrestre
# 2    3     Outubro             Portugal    HM           Terrestre
# 3    4    Setembro             Portugal    HM           Terrestre
# 4    5      Agosto             Portugal    HM           Terrestre
# 5    6       Julho             Portugal    HM           Terrestre
# 6    7       Junho             Portugal    HM           Terrestre
# 7    8        Maio             Portugal    HM           Terrestre
# 8    9       Abril             Portugal    HM           Terrestre
# 9   10       Marco             Portugal    HM           Terrestre
# 10  11   Fevereiro             Portugal    HM           Terrestre
# 11  12     Janeiro             Portugal    HM           Terrestre
#
#      N_de_viagens   Ano
# 0          979908  2020
# 1          541469  2020
# 2          828561  2020
# 3         1398486  2020
# 4         3154781  2020
# 5         1803136  2020
# 6         1136653  2020
# 7          607691  2020
# 8          222200  2020
# 9          489913  2020
# 10        1619564  2020
# 11        1627487  2020

# %% [markdown]
# ## Ano mais antigo em análise

# %%
#função tail lê os últimos dados da tabela, neste caso, definimos que lia os últimos 12
dataframe_tur.tail(12)
# Out:
#       Id       Meses  Local_de_residencia  Sexo  Meio_de_transporte  \
# 120  121    Dezembro             Portugal    HM           Terrestre
# 121  122    Novembro             Portugal    HM           Terrestre
# 122  123     Outubro             Portugal    HM           Terrestre
# 123  124    Setembro             Portugal    HM           Terrestre
# 124  125      Agosto             Portugal    HM           Terrestre
# 125  126       Julho             Portugal    HM           Terrestre
# 126  127       Junho             Portugal    HM           Terrestre
# 127  128        Maio             Portugal    HM           Terrestre
# 128  129       Abril             Portugal    HM           Terrestre
# 129  130       Marco             Portugal    HM           Terrestre
# 130  131   Fevereiro             Portugal    HM           Terrestre
# 131  132     Janeiro             Portugal    HM           Terrestre
#
#       N_de_viagens   Ano
# 120         183057  2010
# 121         881763  2010
# 122         994254  2010
# 123        1145039  2010
# 124        2707859  2010
# 125        1732924  2010
# 126        1259125  2010
# 127         868843  2010
# 128        1130322  2010
# 129         877641  2010
# 130        1036056  2010
# 131         908819  2010

# %% [markdown]
# ## Atribuir a variável principal

# %%
#definimos a variável em análise principal - Número de viagens feitas por turistas - com a função set_index
dataframe_N_de_viagens = dataframe_tur.set_index(" N_de_viagens")

#utilizamos a função head para aparecer os 132 dados em análise
dataframe_N_de_viagens.head(132)
# Out:
#                 Id       Meses  Local_de_residencia  Sexo  Meio_de_transporte  \
#  N_de_viagens
# 979908           1    Dezembro             Portugal    HM           Terrestre
# 541469           2    Novembro             Portugal    HM           Terrestre
# 828561           3     Outubro             Portugal    HM           Terrestre
# 1398486          4    Setembro             Portugal    HM           Terrestre
# 3154781          5      Agosto             Portugal    HM           Terrestre
# ...            ...         ...                  ...   ...                 ...
# 868843         128        Maio             Portugal    HM           Terrestre
# 1130322        129       Abril             Portugal    HM           Terrestre
# 877641         130       Marco             Portugal    HM           Terrestre
# 1036056        131   Fevereiro             Portugal    HM           Terrestre
# 908819         132     Janeiro             Portugal    HM           Terrestre
#
#                 Ano
#  N_de_viagens
# 979908         2020
# 541469         2020
# 828561         2020
# 1398486        2020
# 3154781        2020
# ...             ...
# 868843         2010
# 1130322        2010
# 877641         2010
# 1036056        2010
# 908819         2010
#
# [132 rows x 6 columns]

# %% [markdown]
# ## Descubrir o mês de todos os anos com mais viagens realizadas

# %%
#procuramos o mês com o máximo de variáveis realizadas através da função max, ao definirmos que o máximo em análise estava presente na variável N_de_viagens
total_list = dataframe_tur[' N_de_viagens'].tolist()

max_viagens = dataframe_tur[' N_de_viagens']== max(total_list)

dataframe_tur.loc[max_viagens]
# Out:
#     Id   Meses  Local_de_residencia  Sexo  Meio_de_transporte   N_de_viagens  \
# 78  79   Junho             Portugal    HM           Terrestre       14034976
#
#      Ano
# 78  2014

# %% [markdown]
# ## Responder à questão principal:
# ## Qual o mês do ano de 2020 em que houve mais viagens feitas por turistas?

# %%
#Descubrir o máximo do ano de 2020 utilizando o id, que contrai-se entre 0 e 11 porque ao uilizar os meses, existe subreposição de tosos os anos
lista = dataframe_tur['Id']. between (1,12, inclusive=True)
total_list = dataframe_tur[lista]
numero = total_list[' N_de_viagens'].tolist()
meses = total_list['Id'].tolist()

#definimo o tipo de gráfico através da função plt.plot - gráfico de linha - tal como as suas caracteristicas
plt.plot(meses, numero, 
      color='r', marker='o', markerfacecolor='k', 
      linestyle='-', linewidth=1)

#atribuimos nomes ao x e ao y, ao gráfico e definimos os intervalos do y
plt.xlabel('Meses de 2020')
plt.ylabel('Número de viagens')
plt.legend(loc='upper right')
plt.title('Viagens feitas por turistas mensalmente')
plt.xticks(meses)
plt.yticks([2000000, 4000000, 6000000])
plt.show()
# Out:
# No handles with labels found to put in legend.
